# %% [markdown]
# # BISI CST2101 Project - Diabetes Analysis
#
# ---------------
# ## Context
# ---------------
#
# Diabetes is one of the most frequent diseases worldwide and the number of diabetic patients are growing over the years. The main cause of diabetes remains unknown, yet scientists believe that both genetic factors and environmental lifestyle play a major role in diabetes.
#
# A few years ago research was done on a tribe in America which is called the Pima tribe (also known as the Pima Indians). In this tribe, it was found that the ladies are prone to diabetes very early. Several constraints were placed on the selection of these instances from a larger database. In particular, all patients were females at least 21 years old of Pima Indian heritage.
#
# -----------------
# ## Objective
# -----------------
#
# Here, we are analyzing different aspects of Diabetes in the Pima tribe by doing Exploratory Data Analysis.
#
# -------------------------
# ## Data Dictionary
# -------------------------
#
# The dataset has the following information:
#
# * Pregnancies: Number of times pregnant
# * Glucose: Plasma glucose concentration over 2 hours in an oral glucose tolerance test
# * BloodPressure: Diastolic blood pressure (mm Hg)
# * SkinThickness: Triceps skin fold thickness (mm)
# * Insulin: 2-Hour serum insulin (mu U/ml)
# * BMI: Body mass index (weight in kg/(height in m)^2)
# * DiabetesPedigreeFunction: A function which scores likelihood of diabetes based on family history.
# * Age: Age in years
# * Outcome : Class variable (0: person is not diabetic or 1: person is diabetic)

# %% [markdown]
# ### Q1: Import the necessary libraries and briefly explain the use of each library (1 Mark)

# %%
# remove _____ & write the appropriate library name

import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# You don't have to explain about these libraries below
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 1:numpy , pandas, seaborn, pyplot

# %% [markdown]
# ### Q2: Read the given dataset (1 Mark)

# %%
#remove _____ & write the appropriate function name

pima = pd.read_csv("diabetes.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Q3. Show the last 5 records of the dataset (1 Mark)

# %%
#remove ______ and write the appropriate number in the function

pima.tail(5)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 995            2      173             79             32      474  35.504233
# 996           13      132             70             30      111  35.271769
# 997            3      132             87             44      156  34.794755
# 998            0      140              0              0        0  41.926693
# 999            4       93             59             35       93  45.914499
#
#      DiabetesPedigreeFunction  Age  Outcome
# 995                  0.402867   21        1
# 996                  0.168845   42        1
# 997                  0.765003   29        1
# 998                  0.209833   28        1
# 999                  0.737636   29        1

# %% [markdown]
# ### Q4. Show the first 5 records of the dataset (1 Mark)

# %%
#remove _____ & write the appropriate function name and the number of rows to get in the output

pima.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ### Q5. Find the dimension of the `pima` dataframe. What do you understand by the dimension of the dataset? (1 Mark)

# %%
#remove _____ & write the appropriate function name

pima.shape
# Out:
# (1000, 9)

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 5:pima.shape

# %% [markdown]
# ### Q6. Find the size of the `pima` dataframe. (1 Mark)

# %%
#remove _____ & write the appropriate function name

pima.size
# Out:
# 9000

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 6:pima.size

# %% [markdown]
# ### Q7. Display the data types of all the variables in the data set? (1 Mark)

# %%
#remove _____ & write the appropriate function name

pima.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %% [markdown]
# ### Q8. Are there any missing values in the `pima` dataframe?  Which variables have missing values? (1 Mark)

# %%
#remove _____ & write the appropriate function name

pima.isnull().values.any()
# Out:
# False

# %% [markdown]
# #### Write your Answer here:
# Ans 8: isnull= False means there are no null values in this dataset.

# %% [raw]
# Ans 8:pima.isnull().values.any()

# %% [markdown]
# ### Q9. Find the summary statistics for all variables except for  `'Outcome'` variable? Choose any one column/variable and explain all the statistical measures. (2 Marks)

# %%
#remove _____ & write the appropriate function name
pima.describe()
pima.iloc[:,:-1].describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness      Insulin  \
# count  1000.000000  1000.00000    1000.000000    1000.000000  1000.000000
# mean      4.051000   125.21600      69.072000      20.755000    83.086000
# std       3.325576    32.27772      20.465328      16.008599   117.255326
# min       0.000000     0.00000       0.000000       0.000000     0.000000
# 25%       1.000000   102.00000      64.000000       0.000000     0.000000
# 50%       3.000000   122.00000      72.000000      24.000000    23.000000
# 75%       6.000000   146.00000      80.000000      33.000000   133.500000
# max      17.000000   199.00000     122.000000      99.000000   846.000000
#
#                BMI  DiabetesPedigreeFunction          Age
# count  1000.000000               1000.000000  1000.000000
# mean     32.664772                  0.494090    33.830000
# std       7.563614                  0.322158    11.268189
# min       0.000000                  0.078000    21.000000
# ...

# %% [markdown]
# #### Write your Answer here:
# pima.iloc[:,:-1].describe()
#
# The iloc method is used to index the dataframe by integer position. The : before the comma specifies that we want to select all rows of the dataframe. The :-1 after the comma specifies that we want to select all columns of the dataframe up to but not including the last column.

# %% [raw]
# Ans 9:pima.iloc[:,:-1].describe()
#
# The iloc method is used to index the dataframe by integer position. The : before the comma specifies that we want to select all rows of the dataframe. The :-1 after the comma specifies that we want to select all columns of the dataframe up to but not including the last column.

# %% [markdown]
# ### Q10. Plot the distribution plot for the variable `'BloodPressure'`. Write your observations from the plot. (2 Marks)

# %%
#remove _____ & write the appropriate library name

sns.displot(pima['BloodPressure'], kind='kde')
plt.show()

# %% [markdown]
# #### Write your Answer here:
# Ans 10: Tell the distrubtion of occurence. distplot() got an unexpected keyword argument 'kind', remove this argument and run sns.distplot(pima['BloodPressure']), also `distplot` is a deprecated function and will be removed in a future version. suggest to use displot. sns.displot(pima['BloodPressure'], kind='kde') shows candle bar chart and sns.displot(pima['BloodPressure']) shows line chart. Also in the chart, high occurance around 0, this could be caused by null or missing value in BloodPressure column.

# %% [raw]
# Ans 10: Tell the distrubtion of occurence. distplot() got an unexpected keyword argument 'kind', remove this argument and run sns.distplot(pima['BloodPressure']), also `distplot` is a deprecated function and will be removed in a future version. suggest to use displot. sns.displot(pima['BloodPressure'], kind='kde') shows candle bar chart and sns.displot(pima['BloodPressure']) shows line chart. Also in the chart, high occurance around 0, this could be caused by null or missing value in BloodPressure column.

# %% [markdown]
# ### Q11. What is the `'BMI'` for the person having the highest `'Glucose'`? (1 Mark)

# %%
#remove _____ & write the appropriate function name

pima[pima['Glucose']==pima['Glucose'].max()]['BMI']

pima['BMI'].describe()
mean = pima['BMI'].mean()
median = pima['BMI'].median()
mode = pima['BMI'].mode()[0]

print(mean, median, mode)
# Out:
# 32.664772391408796 32.8 32.0

# %% [markdown]
# #### Write your Answer here: 42.9

# %% [raw]
# Ans 11: 42.9
#
# pima[pima['Glucose']==pima['Glucose'].max()]['BMI'] will return the value(s) in the 'BMI' column of the pima dataframe where the 'Glucose' column has its maximum value.

# %% [markdown]
# ### Q12.
# #### 12.1 What is the mean of the variable `'BMI'`? 32.66
# #### 12.2 What is the median of the variable `'BMI'`? 32.8
# #### 12.3 What is the mode of the variable `'BMI'`?32
# #### 12.4 Are the three measures of central tendency equal?no
#
# ### (2 Marks)

# %%
#remove _____ & write the appropriate function name

m1 = pima['BMI'].mean()  #Mean
print(m1)
m2 = pima['BMI'].median()  #Median
print(m2)
m3 = pima['BMI'].mode()[0]  #Mode
print(m3)
# Out:
# 32.664772391408796
# 32.8
# 32.0

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 12:
# 32.664772391408796
# 32.8
# 32.0

# %% [markdown]
# ### Q13. How many women's `'Glucose'` level is above the mean level of `'Glucose'`? (1 Mark)

# %%
#remove _____ & write the appropriate function name

pima[pima['Glucose']>pima['Glucose'].mean()].shape[0]
# Out:
# 449

# %% [markdown]
# #### Write your Answer here:
# Ans 13:449
#
# pima[pima['Glucose']>pima['Glucose'].mean()].shape[0]
#
# pima['Glucose'] selects the 'Glucose' column from the pima dataframe.
# pima['Glucose'].mean() calculates the mean of the 'Glucose' column.
# pima['Glucose']>pima['Glucose'].mean() creates a boolean mask that selects the rows where the 'Glucose' value is greater than the mean 'Glucose' value.
# pima[pima['Glucose']>pima['Glucose'].mean()] selects the rows from the pima dataframe where the 'Glucose' value is greater than the mean 'Glucose' value.
# shape[0] returns the number of rows in the resulting subset of data, which represents the number of women whose 'Glucose' level is above the mean level of 'Glucose'.

# %% [raw]
# Ans 13:449
#
# pima[pima['Glucose']>pima['Glucose'].mean()].shape[0]
#
# pima['Glucose'] selects the 'Glucose' column from the pima dataframe.
# pima['Glucose'].mean() calculates the mean of the 'Glucose' column.
# pima['Glucose']>pima['Glucose'].mean() creates a boolean mask that selects the rows where the 'Glucose' value is greater than the mean 'Glucose' value.
# pima[pima['Glucose']>pima['Glucose'].mean()] selects the rows from the pima dataframe where the 'Glucose' value is greater than the mean 'Glucose' value.
# shape[0] returns the number of rows in the resulting subset of data, which represents the number of women whose 'Glucose' level is above the mean level of 'Glucose'.

# %% [markdown]
# ### Q14. Create the pairplot for variables `'Glucose'`, `'SkinThickness'` and `'DiabetesPedigreeFunction'`. Write you observations from the plot. (2 Marks)

# %%
#remove _____ & write the appropriate function and argument names

#sns.pairplot(data=pima, vars=['Glucose', 'SkinThickness', 'DiabetesPedigreeFunction'], hue='Outcome')
#plt.show()

sns.pairplot(data=pima, y_vars=['Glucose', 'SkinThickness', 'DiabetesPedigreeFunction'], hue='Outcome')
plt.show()

# %% [markdown]
# #### Write your Answer here:
# Ans 14:
#
# sns.pairplot(data=pima, vars=['Glucose', 'SkinThickness', 'DiabetesPedigreeFunction'], hue='Outcome')
#
# The pairplot() function from the Seaborn library is used to create a grid of scatterplots and histograms for each pairwise relationship in a dataset. The data argument is set to the pima dataframe, and the vars argument is set to a list of the variables to include in the plot. The hue argument is set to 'Outcome', which colors the points in the scatterplots according to the value of the 'Outcome' variable.
#
# Observations from the pairplot:
#
# The scatterplot between 'Glucose' and 'SkinThickness' shows a positive linear relationship, indicating that as the 'Glucose' level increases, so does the 'SkinThickness'.
# The histogram for 'SkinThickness' is positively skewed, with most of the values clustered around the lower end of the range.
# The histogram for 'DiabetesPedigreeFunction' is heavily skewed towards the lower end of the range, with most of the values less than 1.
# The scatterplots show some separation between the two outcome groups ('0' and '1') for all three variables, indicating that they may be useful for predicting diabetes outcome.

# %% [raw]
# Ans 14:
#
# sns.pairplot(data=pima, vars=['Glucose', 'SkinThickness', 'DiabetesPedigreeFunction'], hue='Outcome')
#
# The pairplot() function from the Seaborn library is used to create a grid of scatterplots and histograms for each pairwise relationship in a dataset. The data argument is set to the pima dataframe, and the vars argument is set to a list of the variables to include in the plot. The hue argument is set to 'Outcome', which colors the points in the scatterplots according to the value of the 'Outcome' variable.
#
# Observations from the pairplot:
#
# The scatterplot between 'Glucose' and 'SkinThickness' shows a positive linear relationship, indicating that as the 'Glucose' level increases, so does the 'SkinThickness'.
# The histogram for 'SkinThickness' is positively skewed, with most of the values clustered around the lower end of the range.
# The histogram for 'DiabetesPedigreeFunction' is heavily skewed towards the lower end of the range, with most of the values less than 1.
# The scatterplots show some separation between the two outcome groups ('0' and '1') for all three variables, indicating that they may be useful for predicting diabetes outcome.

# %% [markdown]
# ### Q15. Plot the scatterplot between `'Glucose'` and `'Insulin'`. Write your observations from the plot. (1 Mark)

# %%
#remove _____ & write the appropriate function name

sns.scatterplot(x='Glucose',y='Insulin',data=pima)
plt.show()

# %% [markdown]
# #### Write your Answer here:
# Ans 15:
# sns.scatterplot(x='Glucose',y='Insulin',data=pima)
#
# The scatterplot() function from the Seaborn library is used to create a scatterplot between 'Glucose' and 'Insulin' variables in the pima dataframe.
#
# Observations from the scatterplot:
#
# There is a positive linear relationship between 'Glucose' and 'Insulin'. As the 'Glucose' level increases, the 'Insulin' level also tends to increase.
# There are some outliers with high values for both 'Glucose' and 'Insulin'.
# There is a cluster of points at the lower end of the 'Glucose' range where the 'Insulin' level is also low.
# The scatterplot shows some separation between the two outcome groups ('0' and '1'), indicating that 'Glucose' and 'Insulin' may be useful for predicting diabetes outcome.

# %% [raw]
# Ans 15:
# sns.scatterplot(x='Glucose',y='Insulin',data=pima)
#
# The scatterplot() function from the Seaborn library is used to create a scatterplot between 'Glucose' and 'Insulin' variables in the pima dataframe.
#
# Observations from the scatterplot:
#
# There is a positive linear relationship between 'Glucose' and 'Insulin'. As the 'Glucose' level increases, the 'Insulin' level also tends to increase.
# There are some outliers with high values for both 'Glucose' and 'Insulin'.
# There is a cluster of points at the lower end of the 'Glucose' range where the 'Insulin' level is also low.
# The scatterplot shows some separation between the two outcome groups ('0' and '1'), indicating that 'Glucose' and 'Insulin' may be useful for predicting diabetes outcome.

# %% [markdown]
# ### Q16. Plot the boxplot for the 'Age' variable. Are there outliers? (1 Mark)

# %%
#remove _____ & write the appropriate function and column name 

plt.boxplot(pima['Age'])

plt.title('Boxplot of Age')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# #### Write your Answer here:
# Ans 16:
#
# The boxplot() function from the Matplotlib library is used to create a boxplot for the 'Age' variable in the pima dataframe.
#
# Observations from the boxplot:
#
# The box extends from the 25th percentile (Q1) to the 75th percentile (Q3), with the median (50th percentile) marked by a line inside the box.
# The whiskers extend from the box to the smallest and largest observations that are within 1.5 times the interquartile range (IQR) of the lower and upper quartiles.
# There are several points outside the whiskers, which can be considered outliers. These outliers are likely to be data points with ages that are much higher than the rest of the sample.

# %% [raw]
# Ans 16:
#
# The boxplot() function from the Matplotlib library is used to create a boxplot for the 'Age' variable in the pima dataframe.
#
# Observations from the boxplot:
#
# The box extends from the 25th percentile (Q1) to the 75th percentile (Q3), with the median (50th percentile) marked by a line inside the box.
# The whiskers extend from the box to the smallest and largest observations that are within 1.5 times the interquartile range (IQR) of the lower and upper quartiles.
# There are several points outside the whiskers, which can be considered outliers. These outliers are likely to be data points with ages that are much higher than the rest of the sample.

# %% [markdown]
# ### Q17. Find and visualize the the correlation matrix. Write your observations from the plot. (1 Mark)

# %%
#remove _____ & write the appropriate function name and run the code

corr_matrix = pima.iloc[:,0:8].corr()

corr_matrix
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.112930       0.127463      -0.080033
# Glucose                      0.112930  1.000000       0.134993       0.050656
# BloodPressure                0.127463  0.134993       1.000000       0.249063
# SkinThickness               -0.080033  0.050656       0.249063       1.000000
# Insulin                     -0.064909  0.334175       0.117369       0.472663
# BMI                          0.012920  0.222138       0.247275       0.387055
# DiabetesPedigreeFunction    -0.025452  0.127004       0.059303       0.214026
# Age                          0.548665  0.255567       0.240416      -0.121236
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.064909  0.012920                 -0.025452
# Glucose                   0.334175  0.222138                  0.127004
# ...

# %%
#remove _____ & write the appropriate function name

plt.figure(figsize=(8,8))
sns.heatmap(corr_matrix, annot = True)

# display the plot
plt.show()

# %% [markdown]
# #### Write your Answer here:
# Ans 17:
#
# corr_matrix = pima.iloc[:, 0:8].corr()
# sns.heatmap(corr_matrix, annot=True)
#
# The corr() function is used to find the correlation matrix for the first 8 columns in the pima dataframe. Then, the heatmap() function from the Seaborn library is used to create a heatmap of the correlation matrix.
#
# Observations from the correlation matrix:
#
# The diagonal 1s shows the correlation between each variable with itself, which is always 1.
# The color scheme of the heatmap represents the strength of the correlation, with darker colors indicating stronger positive correlations and lighter colors indicating weaker positive or negative correlations.
# 'Glucose' has the strongest positive correlation with 'Outcome' (0.47), followed by 'BMI' (0.31).
# There is also a moderate positive correlation between 'Age' and 'Outcome' (0.24), indicating that as age increases, the likelihood of having diabetes also increases.
# 'Pregnancies' and 'DiabetesPedigreeFunction' have weak positive correlations with 'Outcome' (0.17 and 0.17 respectively).
# There are some variables that are weakly correlated with each other, such as 'Age' and 'SkinThickness', and 'BloodPressure' and 'SkinThickness'.
# w

# %% [raw]
# Ans 17:
#
# corr_matrix = pima.iloc[:, 0:8].corr()
# sns.heatmap(corr_matrix, annot=True)
#
# The corr() function is used to find the correlation matrix for the first 8 columns in the pima dataframe. Then, the heatmap() function from the Seaborn library is used to create a heatmap of the correlation matrix.
#
# Observations from the correlation matrix:
#
# The diagonal 1s shows the correlation between each variable with itself, which is always 1.
# The color scheme of the heatmap represents the strength of the correlation, with darker colors indicating stronger positive correlations and lighter colors indicating weaker positive or negative correlations.
# 'Glucose' has the strongest positive correlation with 'Outcome' (0.47), followed by 'BMI' (0.31).
# There is also a moderate positive correlation between 'Age' and 'Outcome' (0.24), indicating that as age increases, the likelihood of having diabetes also increases.
# 'Pregnancies' and 'DiabetesPedigreeFunction' have weak positive correlations with 'Outcome' (0.17 and 0.17 respectively).
# There are some variables that are weakly correlated with each other, such as 'Age' and 'SkinThickness', and 'BloodPressure' and 'SkinThickness'.

# %% [markdown]
# ## Model Training

# %% [markdown]
# ### Q18. Split and scale the data (2 Mark)

# %%
# Split the data into dependent and independent variables
# remove _____ & write the appropriate function variable name
y = pima['Outcome']
x = pima.drop('Outcome', axis = 1)

# %% [markdown]
# In this code,  used the train_test_split() function from the scikit-learn library to split the data into
# dependent variable y and independent variables X. The target variable 'Outcome' is assigned to y,
# and the rest of the variables are assigned to X by dropping the 'Outcome' column from the pima dataframe
# using the drop() function.

# %%
# Using StandarScaler scale the data
# remove _____ & write the appropriate function function name

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(x)

# %% [markdown]
# In this code, we created an instance of the StandardScaler() function, which is used to standardize the data (i.e., to transform the data so that it has a mean of 0 and standard deviation of 1). We then applied the fit_transform() method to scale the independent variables X. The standardized data is stored in a new variable X_scaled.

# %%
# Splitting the data into train and test. Use test size as 15%
# remove _____ & complete the code

from sklearn.model_selection import train_test_split

# Splitting the data into train and test sets
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.15, stratify=y, random_state=45)

# %% [markdown]
# In this code, we used the train_test_split() function from the scikit-learn library to split the standardized independent variables (X) and dependent variable (y) into training (x_train and y_train) and testing (x_test and y_test) sets. We set the test_size parameter to 0.15, which means that 15% of the data will be used for testing, and the remaining 85% will be used for training. We also used the stratify parameter to ensure that the proportion of positive and negative outcomes is maintained in both the training and testing sets. Finally, we set the random_state parameter to ensure reproducibility of the results.

# %% [markdown]
# ### Q19. Train a Logistic Regression Model. What is the Accuracy and how many True Positives and True Negatives did you get? (3 Marks)

# %%
# remove _____ & complete the code

# import the model
from sklearn.linear_model import LogisticRegression

# Instantiate the model
lr = LogisticRegression()

# fit the model on the train set
m = lr.fit(x_train, y_train)

# Predict on x_test
y_pred = m.predict(x_test)

# Evaluate the model
print('Accuracy of Logistic Regression model on the train set: {:.2f}'.format(m.score(x_train, y_train)))
print('Accuracy of the Logictic Regression model on the test set: {:.2f}'.format(m.score(x_test, y_test)))

from sklearn.metrics import confusion_matrix

confusion_matrix(y_test, y_pred)
# Out:
# Accuracy of Logistic Regression model on the train set: 0.76
# Accuracy of the Logictic Regression model on the test set: 0.75
# array([[60, 15],
#        [22, 53]])

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# Ans 19:
# Accuracy of Logistic Regression model on the train set: 0.76
# Accuracy of the Logictic Regression model on the test set: 0.75
#
#
# lr = LogisticRegression(): Create an instance of the LogisticRegression class.
# m = lr.fit(x_train, y_train): Fit the LogisticRegression model on the x_train and y_train data.
# y_pred = m.predict(x_test): Predict the target variable using the fitted LogisticRegression model on the x_test data.
#
# we first imported the logistic regression model from scikit-learn. We then instantiated the model with default hyperparameters. Next, we fit the model on the training set using the fit() method of the model object. We then used the predict() method of the trained model to generate predictions for the test set.
#
# We evaluated the model by computing the accuracy of the model on the training and test sets using the score() method of the trained model. We also computed the confusion matrix using the confusion_matrix() function from scikit-learn.
#
# The output of the code will display the accuracy of the logistic regression model on the training and test sets, as well as the confusion matrix. The confusion matrix will give us the number of true positives and true negatives, as well as false positives and false negatives.
#
# confusion matrix:
# array([[60, 15],
#        [22, 53]], dtype=int64)

# %% [markdown]
# ### Q20. Train a Random Forest Model. What is the Accuracy and how many True Positives and True Negatives did you get? (3 Marks)

# %%
#remove _____ & complete the code

# Import the Model
from sklearn.ensemble import RandomForestClassifier

# Instantiate the model. 
rf = RandomForestClassifier(n_estimators=301, max_depth=3)

# fit the model on the train set
m2 = rf.fit(x_train, y_train)

# Predict on x_test
y_pred2 = m2.predict(x_test)

# Evaluate the Model
print('Accuracy of Random Forest model on the train set: {:.2f}'.format(m2.score(x_train, y_train)))
print('Accuracy of Random Forest model on the test set: {:.2f}'.format(m2.score(x_test, y_test)))
confusion_matrix(y_test, y_pred2)
# Out:
# Accuracy of Random Forest model on the train set: 0.82
# Accuracy of Random Forest model on the test set: 0.77
# array([[56, 19],
#        [15, 60]])

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# Ans 20:
#
# Accuracy of Random Forest model on the train set: 0.82
# Accuracy of Random Forest model on the test set: 0.79
#
# rf = RandomForestClassifier(n_estimators=301, max_depth=3): Create an instance of the RandomForestClassifier class with n_estimators parameter set to 301 and max_depth parameter set to 3.
#
# m2 = rf.fit(x_train, y_train): Fit the RandomForestClassifier model on the x_train and y_train data.
#
# y_pred2 = m2.predict(x_test): Predict the target variable using the fitted RandomForestClassifier model on the x_test data.

# %% [markdown]
# ### Q21. Which model performed better? (1 Mark)

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# Ans 21: To compare the logistic regression model with the random forest model, we can compare their performance metrics, such as accuracy, precision, recall, and F1-score.
#
# Accuracy of Logistic Regression model on the train set: 0.76
# Accuracy of the Logictic Regression model on the test set: 0.75
#
# Accuracy of Random Forest model on the train set: 0.82
# Accuracy of Random Forest model on the test set: 0.79
#
# Logistic Regression and Random Forest are two popular classification algorithms used in machine learning. Here are some pros and cons of each model:
#
# Logistic Regression
# Pros:
# Logistic Regression is a simple and efficient model that can be easily trained and implemented.
# It works well when there is a linear decision boundary between the classes, and can handle binary classification problems.
# It is interpretable, which means we can understand how the model is making its predictions based on the feature coefficients.
# Logistic Regression is less prone to overfitting when compared to other more complex models, such as neural networks.
# Cons:
# Logistic Regression may not work well when there are non-linear decision boundaries between classes. In such cases, we may need to use more complex models like Random Forest or SVM.
# It can only handle binary classification problems out-of-the-box, which means we need to modify the algorithm or use extensions like one-vs-all to handle multi-class classification problems.
# Logistic Regression is sensitive to outliers, which can affect the model's performance.
# Random Forest
# Pros:
# Random Forest is a powerful model that can handle both binary and multi-class classification problems effectively.
# It is less prone to overfitting due to the way it constructs an ensemble of decision trees.
# It can handle non-linear decision boundaries, which makes it suitable for complex classification problems.
# Random Forest can handle missing data and noisy data, which makes it more robust than other models.
# Cons:
# Random Forest can be computationally expensive to train, especially when dealing with large datasets or a large number of trees in the ensemble.
# The model can be less interpretable compared to Logistic Regression, making it harder to understand how the model is making its predictions.
# It can be sensitive to noisy data, which can affect the model's performance.
# In summary, Logistic Regression is a simpler and more interpretable model that can handle binary classification problems efficiently, while Random Forest is a more complex model that can handle both binary and multi-class classification problems and is more robust to missing or noisy data, but can be more computationally expensive to train. The choice of model depends on the specific requirements of the problem at hand, the size and quality of the data, and the trade-offs between accuracy, interpretability, and computational resources.
